# %% [markdown]
# 网址：https://motong-ai-studio.top/index.html

# %% [markdown]
# # 主页
#
# 导航栏优化：添加透明度，适应现有三张背景图。
#
# ![image-4.png](attachment:image-4.png)
#
# 研究方向模块：改成两行两列如图
#
# ![image.png](attachment:image.png)
#
# 新增新闻模块：参考如图
#
# ![image-2.png](attachment:image-2.png)
#
# 右侧论文区域悬停显示可设置的预览图及论文期刊信息，右侧通过详情跳转链接，链接占位，更换链接跳转到对应论文界面。
# 更多按钮点击  建议更换成自行分页，样例下图，功能实现但布局会有不同
#
# ![image-3.png](attachment:image-3.png)
#
#
# 活动照片移动至“关于我们”分页

# %% [markdown]
# # 关于我们
# 界面优化，并添加活动照片模块，照片内容三列布局：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 论文成果
#
# ![image.png](attachment:image.png)
#
# 界面优化，调整布局，改为：
#
# ![image-2.png](attachment:image-2.png)
#
# 其中，简介内容最大长度两行，自行添加内容即可，查过省略并添加展开折叠的点击功能，如more 。
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 竞赛成果
#
# 根据年份左侧做一个导航栏，右侧根据年份展示对应的荣誉证书，并设计优化证书的大小和尺寸，保持三列
# ![image-2.png](attachment:image-2.png)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 联系我们
#
#
# 待定中

# %% [markdown]
# # 成果展示
# 疑问点    成果展示部分。应该是做成如图：
#
# ![image.png](attachment:image.png)
#
# 1.从哪里跳转过来？需要示例图片，视觉处理前后的图片。
# 2.只需要做出框架，滑动展示以及上传图片功能，后面的部分您自己写对吗？
